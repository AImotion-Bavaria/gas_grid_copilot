# %%
import jax
import jax.numpy as jnp
from scipy.optimize import root
import matplotlib.pyplot as plt
import numpy as np

# %%
f = lambda x: jnp.sin(4 * (x - 1/4)) + x + x**20 - 1
x = jnp.linspace(0, 1, 100)

fig, ax = plt.subplots()
ax.plot(x, f(x), label='$f(x)$')
ax.axhline(ls='--', c='k')
ax.set_xlabel('$x$', fontsize=12)
ax.set_ylabel('$f(x)$', fontsize=12)
ax.legend(fontsize=12)
plt.show()

# %% [markdown]
# Now let's get the first derivative of this function

# %%
f_ = jax.vmap(jax.grad(f))
x = jnp.linspace(0, 1, 100)

fig, ax = plt.subplots()
ax.plot(x, f(x), label='$f(x)$')
ax.plot(x, f_(x), label="$f'(x)$")
ax.axhline(ls='--', c='k')
ax.set_xlabel('$x$', fontsize=12)
ax.set_ylabel('$f(x)$', fontsize=12)
ax.legend(fontsize=12)
plt.show()

# %%
f_(0.9)
# Out:
# Array(0.27414703, dtype=float32, weak_type=True)
